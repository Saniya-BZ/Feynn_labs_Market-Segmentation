# %% [markdown]
# ##Behavioral segmentation & Geographic segmentation

# %% [markdown]
# #Behavioral

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/EV States.csv')

# %%
df.head()
# Out:
#   Sl. No           State  \
# 0      1  Andhra Pradesh
# 1      2           Assam
# 2      3           Bihar
# 3      4    Chhattisgarh
# 4      5           Delhi
#
#    Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  \
# 0                                              431.0
# 1                                              463.0
# 2                                              252.0
# 3                                              613.0
# 4                                             1395.0
#
#    Two Wheelers (Category L2 (CMVR))  \
# 0                              692.0
# 1                              138.0
# 2                              430.0
# 3                              382.0
# 4                              251.0
#
#    Two Wheelers (Max power not exceeding 250 Watts)  2 Wheelers  \
# 0                                            4689.0      5812.0
# 1                                            1006.0      1607.0
# ...

# %%
df.tail()
# Out:
#         Sl. No                                              State  \
# 30         NaN                                                NaN
# 31         NaN                                                NaN
# 32      Source     Electric Vehicles Sales report in india - 2018
# 33  Additional  Sales of electric vehicles across India from f...
# 34  Additional  Reasons for preferring an electric car over a ...
#
#     Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  \
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
#
#     Two Wheelers (Category L2 (CMVR))  \
# 30                                NaN
# 31                                NaN
# 32                                NaN
# 33                                NaN
# ...

# %%
df.shape
# Out:
# (35, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 12 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Sl. No                                                              33 non-null     object
#  1   State                                                               33 non-null     object
#  2   Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  30 non-null     float64
#  3   Two Wheelers (Category L2 (CMVR))                                   30 non-null     float64
#  4   Two Wheelers (Max power not exceeding 250 Watts)                    30 non-null     float64
#  5   2 Wheelers                                                          30 non-null     float64
#  6   Three Wheelers (Category L5 slow speed as per CMVR)                 33 non-null     object
# ...

# %%
df.sum(numeric_only=True)
# Out:
# Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules     27549.0
# Two Wheelers (Category L2 (CMVR))                                      14069.0
# Two Wheelers (Max power not exceeding 250 Watts)                      112538.0
# 2 Wheelers                                                            154156.0
# Three Wheelers (Category L5 as per CMVR)                                 720.0
# 3 Wheelers                                                              1109.0
# Cars                                                                  105571.0
# Buses                                                                     27.0
# Total in state                                                        260863.0
# dtype: float64

# %%
df.isnull().sum()
# Out:
# Sl. No                                                                2
# State                                                                 2
# Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules    5
# Two Wheelers (Category L2 (CMVR))                                     5
# Two Wheelers (Max power not exceeding 250 Watts)                      5
# 2 Wheelers                                                            5
# Three Wheelers (Category L5 slow speed as per CMVR)                   2
# Three Wheelers (Category L5 as per CMVR)                              5
# 3 Wheelers                                                            5
# Cars                                                                  5
# Buses                                                                 5
# Total in state                                                        5
# dtype: int64

# %%
df.describe()
# Out:
#        Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  \
# count                                          30.000000
# mean                                          918.300000
# std                                          1482.441466
# min                                             0.000000
# 25%                                            19.000000
# 50%                                           447.500000
# 75%                                           762.500000
# max                                          7182.000000
#
#        Two Wheelers (Category L2 (CMVR))  \
# count                          30.000000
# mean                          468.966667
# std                           625.711098
# min                             0.000000
# 25%                            18.500000
# 50%                           222.500000
# 75%                           706.250000
# max                          2355.000000
#
# ...

# %%
print(df.describe())
# Out:
#        Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules  \
# count                                          30.000000
# mean                                          918.300000
# std                                          1482.441466
# min                                             0.000000
# 25%                                            19.000000
# 50%                                           447.500000
# 75%                                           762.500000
# max                                          7182.000000
#
#        Two Wheelers (Category L2 (CMVR))  \
# count                          30.000000
# mean                          468.966667
# std                           625.711098
# min                             0.000000
# 25%                            18.500000
# 50%                           222.500000
# 75%                           706.250000
# max                          2355.000000
#
# ...

# %%
df.columns
# Out:
# Index(['Sl. No', 'State',
#        'Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules',
#        'Two Wheelers (Category L2 (CMVR))',
#        'Two Wheelers (Max power not exceeding 250 Watts)', '2 Wheelers',
#        'Three Wheelers (Category L5 slow speed as per CMVR)',
#        'Three Wheelers (Category L5 as per CMVR)', '3 Wheelers', 'Cars',
#        'Buses', 'Total in state'],
#       dtype='object')

# %%
df.fillna(0, inplace=True)

# %%
y = [
    'Two Wheelers (Category L1 & L2 as per Central Motor Vehicles Rules',
    'Two Wheelers (Category L2 (CMVR))',
    'Two Wheelers (Max power not exceeding 250 Watts)',
    'Three Wheelers (Category L5 slow speed as per CMVR)',
    'Three Wheelers (Category L5 as per CMVR)',
    'Cars',
    'Buses',
    'Total in state'
]

import matplotlib.pyplot as plt

color_map = plt.get_cmap('tab20')  # Choose a colormap with enough distinct colors

for a in y:
    if a in df.columns:  # Ensure the column exists
        if pd.api.types.is_numeric_dtype(df[a]):  # Ensure the column has numeric data
            plt.figure(figsize=(20, 10))
            df_sorted = df.sort_values(a, ascending=True)
            top_5 = df_sorted.tail(5)
            # Create a list of colors corresponding to the number of bars
            bar_colors = [color_map(i / len(top_5)) for i in range(len(top_5))]
            top_5.plot.barh(x='State', y=a, color=bar_colors)
            plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
            plt.title(f'Top 5 States by {a}')
            plt.show()
        else:
            print(f"Column '{a}' is not numeric and cannot be plotted.")
    else:
        print(f"Column '{a}' not found in DataFrame.")
# Out:
# Column 'Three Wheelers (Category L5 slow speed as per CMVR)' is not numeric and cannot be plotted.

# %% [markdown]
# #Geographic Segmentation:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('/content/1_ev_charger_dataset.csv')

# %%
df.head()
# Out:
#           Region     2W     3W    4W  Bus  Chargers
# 0  Uttar Pradesh   9852  42881   458  197       207
# 1     Maharastra  38558    893  1895  186       317
# 2      Karnataka  32844    568   589   57       172
# 3     Tamil Nadu  25642    396   426    0       256
# 4        Gujarat  22359    254   423   22       228

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Region    24 non-null     object
#  1   2W        24 non-null     int64
#  2   3W        24 non-null     int64
#  3   4W        24 non-null     int64
#  4   Bus       24 non-null     int64
#  5   Chargers  24 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.2+ KB

# %%
df.shape
# Out:
# (24, 6)

# %%
df.describe()
# Out:
#                  2W            3W           4W         Bus    Chargers
# count     24.000000     24.000000    24.000000   24.000000   24.000000
# mean    8421.458333   3853.166667   334.041667   28.500000  106.791667
# std    10942.261145   8850.690961   476.930628   63.771331   96.623869
# min      187.000000    234.000000    12.000000    0.000000   10.000000
# 25%      848.000000    512.750000    34.750000    0.000000   25.000000
# 50%     2967.500000    931.000000   129.000000    0.000000   67.500000
# 75%    10697.750000   2659.250000   434.000000    5.500000  180.250000
# max    38558.000000  42881.000000  1895.000000  197.000000  317.000000

# %%
# charging stations sanctioned visualization
plt.figure(figsize=(6, 6))
sns.barplot(data=df, y=df['Region'].sort_values(ascending=True), x='Chargers', palette='viridis')
plt.ylabel('State', fontsize=14, family='serif')
plt.xlabel('Number of Charging Stations', family='serif', fontsize=14, labelpad=10)
plt.xticks(family='serif')
plt.yticks(family='serif')
plt.title(label='Number of Charging Stations Sanctioned in India', weight=200, family='serif', size=15, pad=12)
plt.show()
# Out:
# <ipython-input-20-897aa9842abb>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, y=df['Region'].sort_values(ascending=True), x='Chargers', palette='viridis')

# %% [markdown]
# Observation: Maharashtra, Gujarat, Karnataka, Kerala, Uttar Pradesh, Rajasthan, and Andhra Pradhesh are among the top states with the majority of EV charging stations sanctioned while the remaining states have less number of the same.
